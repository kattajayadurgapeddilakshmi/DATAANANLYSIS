# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
diamonds=sns.load_dataset("diamonds")
print(diamonds)
sns.violinplot(x="clarity",y="price",data=diamonds)
plt.title("prices and attributes of diamonds ")
plt.xlabel("clarity")
plt.ylabel("price")
plt.show()
diamonds.to_csv("diamonddatabase.csv")
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
diamonds=sns.load_dataset("diamonds")
print(diamonds)
sns.violinplot(x="clarity",y="price",data=diamonds)
plt.title("prices and attributes of diamonds ")
plt.xlabel("clarity")
plt.ylabel("price")
plt.show()
import pandas as pd
# Load the diamond database from a CSV file
diamonddatabase = pd.read_csv("/content/diamonddatabase.csv")

# Print the diamond database
print(diamonddatabase)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/diamonddatabase.csv")
print(df.head())
print(df.tail(n=10))
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53930       53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53931       53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53932       53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
# 53933       53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/diamonddatabase.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               1   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               2   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               3   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               4   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/diamonddatabase.csv")
print(df.describe().T)
# Out:
#               count          mean           std    min       25%       50%  \
# Unnamed: 0  53940.0  26969.500000  15571.281097    0.0  13484.75  26969.50
# carat       53940.0      0.797940      0.474011    0.2      0.40      0.70
# depth       53940.0     61.749405      1.432621   43.0     61.00     61.80
# table       53940.0     57.457184      2.234491   43.0     56.00     57.00
# price       53940.0   3932.799722   3989.439738  326.0    950.00   2401.00
# x           53940.0      5.731157      1.121761    0.0      4.71      5.70
# y           53940.0      5.734526      1.142135    0.0      4.72      5.71
# z           53940.0      3.538734      0.705699    0.0      2.91      3.53
#
#                  75%       max
# Unnamed: 0  40454.25  53939.00
# carat           1.04      5.01
# depth          62.50     79.00
# table          59.00     95.00
# price        5324.25  18823.00
# x               6.54     10.74
# y               6.54     58.90
# z               4.04     31.80

# %%
df = pd.read_csv("/content/diamonddatabase.csv")
print(df.shape) #get the number of rows and columns
print(df.shape[0]) #get the number of rows only
print(df.shape[1]) #get the number of columns only
# Out:
# (53940, 11)
# 53940
# 11

# %%
df = pd.read_csv("/content/diamonddatabase.csv")
print(df.columns)
l1 = list(df.columns)
print(l1)
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')
# ['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
df = pd.read_csv("/content/diamonddatabase.csv")
df2=df.copy()
df2.loc[2:5,'cut']=7
df2.head(7)
df2.isnull().head(7)
df.isnull().tail(7)
df2.isnull().sum()
#extracing column
print(df['cut'])
print(df2[['cut','carat']])
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object
#              cut  carat
# 0          Ideal   0.23
# 1        Premium   0.21
# 2              7   0.23
# 3              7   0.29
# 4              7   0.31
# ...          ...    ...
# 53935      Ideal   0.72
# 53936       Good   0.72
# 53937  Very Good   0.70
# 53938    Premium   0.86
# 53939      Ideal   0.75
#
# [53940 rows x 2 columns]

# %%
# printing multiple rows
print(df[2:5])
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 2           2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#printing one row as series
print(df2.loc[3])
# Out:
# Unnamed: 0       3
# carat         0.29
# cut              7
# color            I
# clarity        VS2
# depth         62.4
# table         58.0
# price          334
# x              4.2
# y             4.23
# z             2.63
# Name: 3, dtype: object

# %%
df = pd.read_csv("/content/diamonddatabase.csv")
df.loc[6:11,'cut']=None
print(df)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               1   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               2   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               3   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               4   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df2.loc[6:11,['cut','carat']]
# Out:
#           cut  carat
# 6   Very Good   0.24
# 7   Very Good   0.26
# 8        Fair   0.22
# 9   Very Good   0.23
# 10       Good   0.30
# 11      Ideal   0.23

# %%
df2.iloc[10:14, :3] #[row,column]
# Out:
#     Unnamed: 0  carat      cut
# 10          10   0.30     Good
# 11          11   0.23    Ideal
# 12          12   0.22  Premium
# 13          13   0.31    Ideal

# %%
df2.loc[[10,2,7]]
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 10          10   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 2            2   0.23          7     E     VS1   56.9   65.0    327  4.05
# 7            7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
#
#        y     z
# 10  4.28  2.73
# 2   4.07  2.31
# 7   4.11  2.53

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a Pandas DataFrame
data = pd.DataFrame({'x': x, 'y': y})

# Create a Seaborn linear plot
sns.lmplot(x='x', y='y', data=data, fit_reg=True)
 # Show the plot
plt.show()
