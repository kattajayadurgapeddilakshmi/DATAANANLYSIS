# %%
import pandas as pd
a = ['Jwalitha','Ramya','Durga','Jahnavi','Lahari','Sunny','Dhanush']
r = pd.Series(a, index= [67,43,44,89,34,45,23])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Durga
# 89     Jahnavi
# 34      Lahari
# 45       Sunny
# 23     Dhanush
# dtype: object

# %%
dfn = dfn.drop_duplicates()
print(dfn)

# %%
df = pd.read_csv("/content/diabetcsv.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b65eb5b132d5> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/diabetcsv.csv")
#       2 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7dfd7a8311b4> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/grades_withnulls.csv")
#       2 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/diabet.xlsx.xlsx",sheet_name=0)
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.head())
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.describe().T)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.shape) #get the number of rows and columns
print(df.shape[0]) #get the number of rows only
print(df.shape[1]) #get the number of columns only
# Out:
# (17, 7)
# 17
# 7

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.columns)
l1 = list(df.columns)
print(l1)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'sEM1']=7
df2.head(7)
df2.isnull().head(7)
df.isnull().tail(7)
df2.isnull().sum()
#extracing column
print(df['SEM1'])
print(df2[['SEM1','Names']])
# Out:
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
#printing one row
print(df[df.index==1])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#printing multiple rows
print(df[df.index.isin(range(2,5))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
#printing one row as series
print(df2.loc[3])
# Out:
# Names       Mary
# Initials       N
# SEM1         7.7
# SEM2         8.0
# SEM3         NaN
# Grade          B
# Placed         0
# sEM1         7.0
# Name: 3, dtype: object

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
df.loc[6:11,'SEM1']=None
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   NaN   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   NaN   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2.loc[6:11,['SEM1','Names']]
# Out:
#     SEM1   Names
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya

# %%
df2.loc[[10,2,7]]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 10   Kiran        V   NaN   9.3   9.2     A       0   NaN
# 2   Kissan        V   9.9   9.8  10.0     A       0   7.0
# 7     Mari        N   7.7   8.0   7.1     B       1   NaN

# %%
df2.loc[10:15, ['SEM1','Names',]]
# Out:
#     SEM1   Names
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana

# %%
df2.iloc[10:14, :3] #[row,column]
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df2.loc[:7,["SEM1"]] #[row,column]
# Out:
#    SEM1
# 0   9.8
# 1   8.9
# 2   9.9
# 3   7.7
# 4   9.8
# 5   8.9
# 6   9.9
# 7   7.7

# %%
df2.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 1   Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 13  Rajesh        M   8.9   9.1   9.3     A       1   NaN

# %%
df[df.SEM1=='39']
df[df.Marks==846.0]
# Out:
#     preg  plas  pres  skin  insu  mass   pedi  age            class
# 13     1   189    60    23   846  30.1  0.398   59  tested_positive

# %%
df.loc[df['SEM1']>9.8,['Names']]#printing SEM1  of more than 9.8 in Marks
# Out:
#      Names
# 2   Kissan
# 15    Sana

# %%
df3=df2.copy()
print(df3)
df3=df3.dropna()
print(df3)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 0      Joe        K   9.8  10.0   9.9    A+       1   NaN
# 1   Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 2   Kissan        V   9.9   9.8  10.0     A       0   7.0
# 3     Mary        N   7.7   8.0   NaN     B       0   7.0
# 4     Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5      Raj        M   8.9   9.1   9.3     A       1   7.0
# 6   Hassan        V   9.9   9.0   9.2     A       1   NaN
# 7     Mari        N   7.7   8.0   7.1     B       1   NaN
# 8     Jess        K   NaN   9.1   9.9    A+       1   NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0   NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0   NaN
# 11    Maya        N   7.7   8.0   7.1     B       0   NaN
# 12   Jolin        K   9.8   9.1   9.9    A+       1   NaN
# 13  Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 14    Riya        M   9.3   9.9  10.0     A       1   NaN
# ...

# %%
df3.dropna(inplace=True,axis=1)#inplace says not to reflectchange in the df
print(df3)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 2  Kissan        V   9.9   9.8  10.0     A       0   7.0
# 4    Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5     Raj        M   8.9   9.1   9.3     A       1   7.0

# %%
df3.dropna(inplace=True,how='all') #drop both rows and columns  not NaN
print(df3)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 2  Kissan        V   9.9   9.8  10.0     A       0   7.0
# 4    Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5     Raj        M   8.9   9.1   9.3     A       1   7.0

# %%
mv = df3['SEM1'].mean()
df4 = df3.fillna(mv)
print(df4)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sEM1
# 2  Kissan        V   9.9   9.8  10.0     A       0   7.0
# 4    Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5     Raj        M   8.9   9.1   9.3     A       1   7.0

# %%
df3= pd.read_csv("/content/grades_withnulls.csv")
mv = df3['SEM1'].mean()
df4 = df3.fillna(mv)
print(df4)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
df3 = df4.drop_duplicates()
print(df3)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 GPA  Placed
# 0      Joe        K  9.800000  10.0   9.900000  A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000   A       1
# 2   Kissan        V  9.900000   9.8  10.000000   A       0
# 3     Mary        N  7.700000   8.0   8.992857   B       0
# 4     Jeen        K  9.800000   9.1   9.900000  A+       1
# 5      Raj        M  8.900000   9.1   9.300000   A       1
# 6   Hassan        V  9.900000   9.0   9.200000   A       1
# 7     Mari        N  7.700000   8.0   7.100000   B       1
# 8     Jess        K  8.992857   9.1   9.900000  A+       1
# 9   Rajini        M  8.992857   9.1   9.300000   A       0
# 10   Kiran        V  8.992857   9.3   9.200000   A       0
# 11    Maya        N  7.700000   8.0   7.100000   B       0
# 12   Jolin        K  9.800000   9.1   9.900000  A+       1
# 14    Riya        M  9.300000   9.9  10.000000   A       1
# 15    Sana        V  9.900000   9.3   9.200000   A       0
# ...

# %%
df4.rename(columns = {'Grade':'GPA'}, inplace = True)
df4.head()
# Out:
#     Names Initials  SEM1  SEM2       SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.900000  A+       1
# 1  Rajesh        M   8.9   9.1   9.300000   A       1
# 2  Kissan        V   9.9   9.8  10.000000   A       0
# 3    Mary        N   7.7   8.0   8.992857   B       0
# 4    Jeen        K   9.8   9.1   9.900000  A+       1
